# %%
# !pip install biopython
from Bio import SeqIO

# %%
from datetime import datetime

# %% [markdown]
# # Proccessing data base

# %%
# Run this first to Create Data Dictionaries (Habitat, Taxa, Cog_info)
# Creating Taxa Dictionary
def process_taxa_file():
    data_dict = {}
    with open(taxa_file_name, 'r') as file:
        for line in file:
            parts = line.strip().split(',')
            strain_id = parts[-3]
            bacteria_id = parts[-4]
            phylum_name = parts[1]
            list = [strain_id, phylum_name]
            if (strain_id!='strain_id'):
              data_dict[bacteria_id] = list
    return data_dict

# # Creating cog_info Dictionary
def process_cog_info_file(file_name, encoding='utf-8'):
    data_dict = {}
    with open(file_name, 'r', encoding=encoding, errors='replace') as file:
        for line_number, line in enumerate(file, start=1):
            try:
                parts = line.strip().split(';')
                if len(parts) == 6:
                    cog = parts[0]
                    key = cog[3:]
                    value = parts[1]+';'+parts[2]+';'+parts[3]+';'+parts[4]
                    data_dict[key] = value

            except UnicodeDecodeError as e:
                print(f"Error decoding line {line_number}: {e}")
                print(f"Problematic line content: {line}")
    return data_dict



# Creating Habitat Dictionary
def process_habitat_file():
    data_dict = {}
    with open(habitat_file_name, 'r') as file:
        for line in file:
            parts = line.strip().split(';')
            host_name = parts[1]
            habitat = parts[-1]
            if (host_name!='bacteria'):
              data_dict[host_name] = habitat
    return data_dict


# Main Code

taxa_file_name = 'taxa.txt'
taxa_dict = process_taxa_file()

habitat_file_name = 'habitat.txt'
habitat_dict = process_habitat_file()

cog_file_name = 'COG_INFO_TABLE.txt'
cog_dict = process_cog_info_file(cog_file_name)

# %% [markdown]
# # Extracring information

# %%
class Genome:
    def __init__(self, Genome_id, creature_name):
        self.Genome_id = Genome_id
        self.creature_name = creature_name
        self.segments = []

def process_file(filename):
    Genomes = {}
    with open(filename, 'r') as file:
        for line in file:
            parts = line.strip().split('#')
            creature_name = parts[3]
            Genome_id = parts[1]
            if Genome_id not in Genomes:
                Genomes[Genome_id] = Genome(Genome_id, creature_name)
            genome = Genomes[Genome_id]
            segments = parts[-1].split()
            current_segment = []
            for segment in segments:
                if segment.isdigit() and len(segment) == 4:
                    current_segment.append(segment)
                else:
                    if current_segment:
                        genome.segments.append(current_segment)
                    current_segment = []
            if current_segment:
                genome.segments.append(current_segment)
    return Genomes

def get_clusters_of_length_d_at_least_q_times(Genomes, d, q):
    segment_counts = {}

    for Genome_id, Genome in Genomes.items():
        for segment in Genome.segments:
            if len(segment) >= d:
                for i in range(len(segment) - d + 1):
                    sub_segment = segment[i:i+d]
                    segment_tuple = tuple(sorted(sub_segment))
                    if segment_tuple in segment_counts:
                        if Genome_id not in segment_counts[segment_tuple]:
                            segment_counts[segment_tuple][Genome_id] = (sub_segment, Genome.creature_name)
                    else:
                        segment_counts[segment_tuple] = {Genome_id: (sub_segment, Genome.creature_name)}

    filtered_clusters = {}
    for segment, genomes in segment_counts.items():
        if len(genomes) >= q:
            filtered_clusters[segment] = genomes
    top_clusters = dict(sorted(filtered_clusters.items(), key=lambda item: len(item[1]), reverse=True)[:5])
    return top_clusters

# Main code
q = 4
d = 2
while (d<5):
  #noa: why d<5?
  filename = 'cog_words_plasmid.txt'
  start_time = datetime.now()
  Genomes = process_file(filename)

  selected_lists = get_clusters_of_length_d_at_least_q_times(Genomes, d, q)
  timedelta = datetime.now() - start_time
  print(timedelta)
  print()
  #noa: why top 5?
  print(" "*30 + "Top 5 clusters of length", d, "appearing at least", q, "times:")
  print()
  for segment, cluster_info in selected_lists.items():
      print("Cluster:", segment)
      print("Occurrences:", len(cluster_info))
      print("Genome ID's and Creature Names:")
      for genome_id, (order, creature_name) in cluster_info.items():
          print(f"\tGenome ID: {genome_id}, Creature Name: {creature_name}, Order: {order}")
      print("First Instance of this Cluster:", next(iter(cluster_info.values()))[0])
      print("Information about the COG's:")
      for cog in segment:
        if cog in cog_dict:
          print("\t COG",cog, ":", cog_dict[cog])
        else:
          print("\t COG",cog, ":", "No Information was found for this COG")
      print("Statistics about the different orders we found:")
      word_counter = {}
      host_list = {}
      for value in cluster_info.values():
        word_string = ', '.join(value[0])
        word_counter[word_string] = word_counter.get(word_string, 0) + 1
        host_name = value[1]
        if word_string in host_list:
          host_list[word_string].append(host_name)
        else:
          host_list[word_string]= []
          host_list[word_string].append(host_name)
      for key, value in word_counter.items():
        print("\t [", key , "]:", value, "times out of", len(cluster_info), "which is", round(100*int(value)/len(cluster_info),2), "percent")
      print("Statistics about the Phylum:")
      for order in host_list.keys():
        print("\t Order: [", order , "] - Appears in these Phylum:")
        phylum_counter = {}
        total_hosts = len(host_list[order])
        for host in host_list[order]:
          curr_phylum = taxa_dict[host][1]
          phylum_counter[curr_phylum] = phylum_counter.get(curr_phylum, 0) + 1
        for key, value in phylum_counter.items():
          print("\t\t", key, "-", value, "times out of", total_hosts, ",which is", round(100*int(value)/total_hosts,2), "percent")
      print("Statistics about the Habitat:")
      for order in host_list.keys():
        print("\t Order: [", order , "] - Appears in these Habitats:")
        habitat_counter = {}
        total_hosts = len(host_list[order])
        for host in host_list[order]:
          curr_habitat = habitat_dict[host]
          habitat_counter[curr_habitat] = habitat_counter.get(curr_habitat, 0) + 1
        for key, value in habitat_counter.items():
          print("\t\t", key, "-", value, "times out of", total_hosts, ",which is", round(100*int(value)/total_hosts,2), "percent")
      print()
      print("*"*100)
  d = d+1
  print("*"*100)
  print("*"*100)
# Out:
# 0:00:00.230021
#
#                               Top 5 clusters of length 2 appearing at least 4 times:
#
# Cluster: ('1192', '1475')
# Occurrences: 309
# Genome ID's and Creature Names:
# 	Genome ID: NC_009926, Creature Name: Acaryochloris_marina_MBIC11017_uid58167, Order: ['1192', '1475']
# 	Genome ID: NC_009927, Creature Name: Acaryochloris_marina_MBIC11017_uid58167, Order: ['1192', '1475']
# 	Genome ID: NC_009928, Creature Name: Acaryochloris_marina_MBIC11017_uid58167, Order: ['1192', '1475']
# 	Genome ID: NC_009930, Creature Name: Acaryochloris_marina_MBIC11017_uid58167, Order: ['1192', '1475']
# 	Genome ID: NC_009931, Creature Name: Acaryochloris_marina_MBIC11017_uid58167, Order: ['1192', '1475']
# 	Genome ID: NC_013210, Creature Name: Acetobacter_pasteurianus_IFO_3283_01_uid59279, Order: ['1192', '1475']
# 	Genome ID: NC_014641, Creature Name: Achromobacter_xylosoxidans_A8_uid59899, Order: ['1192', '1475']
# 	Genome ID: NC_014642, Creature Name: Achromobacter_xylosoxidans_A8_uid59899, Order: ['1192', '1475']
# 	Genome ID: NC_009467, Creature Name: Acidiphilium_cryptum_JF_5_uid58447, Order: ['1192', '1475']
# 	Genome ID: NC_015178, Creature Name: Acidiphilium_multivorum_AIU301_uid63345, Order: ['1192', '1475']
# 	Genome ID: NC_015851, Creature Name: Acidithiobacillus_caldus_SM_1_uid70791, Order: ['1192', '1475']
# 	Genome ID: NC_008765, Creature Name: Acidovorax_JS42_uid58427, Order: ['1192', '1475']
# 	Genome ID: NC_008766, Creature Name: Acidovorax_JS42_uid58427, Order: ['1192', '1475']
# Information about the COG's:
# 	 COG 1192 : N;CELLULAR PROCESSES AND SIGNALING;Cell motility;Cellulose biosynthesis protein BcsQ
# 	 COG 1475 : D;CELLULAR PROCESSES AND SIGNALING;Cell cycle control, cell division, chromosome partitioning;Chromosome segregation protein Spo0J, contains ParB-like nuclease domain
# Statistics about the different orders we found:
# 	 [ 1192, 1475 ]: 303 times out of 309 which is 98.06 percent
# 	 [ 1475, 1192 ]: 6 times out of 309 which is 1.94 percent
# Statistics about the Phylum:
# 	 Order: [ 1192, 1475 ] - Appears in these Phylum:
# 		 Cyanobacteria - 25 times out of 303 ,which is 8.25 percent
# 		 Proteobacteria - 246 times out of 303 ,which is 81.19 percent
# 		 Deferribacteres - 2 times out of 303 ,which is 0.66 percent
# 		 - - 15 times out of 303 ,which is 4.95 percent
# 		 Spirochaetes - 3 times out of 303 ,which is 0.99 percent
# 		 Actinobacteria - 9 times out of 303 ,which is 2.97 percent
# 		 Firmicutes - 2 times out of 303 ,which is 0.66 percent
# 		 Chloroflexi - 1 times out of 303 ,which is 0.33 percent
# 	 Order: [ 1475, 1192 ] - Appears in these Phylum:
# 		 Proteobacteria - 1 times out of 6 ,which is 16.67 percent
# 		 Actinobacteria - 4 times out of 6 ,which is 66.67 percent
# 		 Crenarchaeota - 1 times out of 6 ,which is 16.67 percent
# Statistics about the Habitat:
# 	 Order: [ 1192, 1475 ] - Appears in these Habitats:
# 		 Marine Environment - 20 times out of 303 ,which is 6.6 percent
# 		 Not Annotated - 24 times out of 303 ,which is 7.92 percent
# 		 Soil and Sediment - 79 times out of 303 ,which is 26.07 percent
# 		 Host - 45 times out of 303 ,which is 14.85 percent
# 		 Fresh water - 39 times out of 303 ,which is 12.87 percent
# 		 Animal - 14 times out of 303 ,which is 4.62 percent
# 		 Plant - 45 times out of 303 ,which is 14.85 percent
# 		 Wastewater - 7 times out of 303 ,which is 2.31 percent
# 		 Human - 20 times out of 303 ,which is 6.6 percent
# 		 Extreme Environments - 10 times out of 303 ,which is 3.3 percent
# 	 Order: [ 1475, 1192 ] - Appears in these Habitats:
# 		 Not Annotated - 2 times out of 6 ,which is 33.33 percent
# 		 Soil and Sediment - 4 times out of 6 ,which is 66.67 percent
#
# ****************************************************************************************************
# Cluster: ('1484', '4584')
# Occurrences: 128
# Genome ID's and Creature Names:
# 	Genome ID: NC_009927, Creature Name: Acaryochloris_marina_MBIC11017_uid58167, Order: ['4584', '1484']
# 	Genome ID: NC_013211, Creature Name: Acetobacter_pasteurianus_IFO_3283_01_uid59279, Order: ['4584', '1484']
# 	Genome ID: NC_014641, Creature Name: Achromobacter_xylosoxidans_A8_uid59899, Order: ['4584', '1484']
# 	Genome ID: NC_009467, Creature Name: Acidiphilium_cryptum_JF_5_uid58447, Order: ['4584', '1484']
# 	Genome ID: NC_009468, Creature Name: Acidiphilium_cryptum_JF_5_uid58447, Order: ['4584', '1484']
# 	Genome ID: NC_009469, Creature Name: Acidiphilium_cryptum_JF_5_uid58447, Order: ['4584', '1484']
# 	Genome ID: NC_009471, Creature Name: Acidiphilium_cryptum_JF_5_uid58447, Order: ['4584', '1484']
# 	Genome ID: NC_015178, Creature Name: Acidiphilium_multivorum_AIU301_uid63345, Order: ['4584', '1484']
# 	Genome ID: NC_015187, Creature Name: Acidiphilium_multivorum_AIU301_uid63345, Order: ['4584', '1484']
# 	Genome ID: NC_015851, Creature Name: Acidithiobacillus_caldus_SM_1_uid70791, Order: ['4584', '1484']
# 	Genome ID: NC_009349, Creature Name: Aeromonas_salmonicida_A449_uid58631, Order: ['4584', '1484']
# 	Genome ID: NC_009350, Creature Name: Aeromonas_salmonicida_A449_uid58631, Order: ['4584', '1484']
# 	Genome ID: NC_011986, Creature Name: Agrobacterium_vitis_S4_uid58249, Order: ['4584', '1484']
# 	Genome ID: NC_011991, Creature Name: Agrobacterium_vitis_S4_uid58249, Order: ['4584', '1484']
# 	Genome ID: NC_014908, Creature Name: Alicycliphilus_denitrificans_BC_uid49953, Order: ['4584', '1484']
# 	Genome ID: NC_014911, Creature Name: Alicycliphilus_denitrificans_BC_uid49953, Order: ['4584', '1484']
# 	Genome ID: NC_006823, Creature Name: Aromatoleum_aromaticum_EbN1_uid58231, Order: ['4584', '1484']
# 	Genome ID: NC_006824, Creature Name: Aromatoleum_aromaticum_EbN1_uid58231, Order: ['4584', '1484']
# 	Genome ID: NC_008712, Creature Name: Arthrobacter_aurescens_TC1_uid58109, Order: ['4584', '1484']
# 	Genome ID: NC_015146, Creature Name: Arthrobacter_phenanthrenivorans_Sphe3_uid63629, Order: ['4584', '1484']
# 	Genome ID: NC_013855, Creature Name: Azospirillum_B510_uid46085, Order: ['4584', '1484']
# 	Genome ID: NC_013856, Creature Name: Azospirillum_B510_uid46085, Order: ['4584', '1484']
# 	Genome ID: NC_013857, Creature Name: Azospirillum_B510_uid46085, Order: ['4584', '1484']
# 	Genome ID: NC_013859, Creature Name: Azospirillum_B510_uid46085, Order: ['4584', '1484']
# 	Genome ID: NC_013860, Creature Name: Azospirillum_B510_uid46085, Order: ['4584', '1484']
# 	Genome ID: NC_011655, Creature Name: Bacillus_cereus_AH187_uid58753, Order: ['4584', '1484']
# 	Genome ID: NC_011973, Creature Name: Bacillus_cereus_Q1_uid58529, Order: ['4584', '1484']
# 	Genome ID: NC_013792, Creature Name: Bacillus_pseudofirmus_OF4_uid45847, Order: ['4584', '1484']
# 	Genome ID: NC_013793, Creature Name: Bacillus_pseudofirmus_OF4_uid45847, Order: ['4584', '1484']
# 	Genome ID: NC_009475, Creature Name: Bradyrhizobium_BTAi1_uid58505, Order: ['4584', '1484']
# 	Genome ID: NC_014120, Creature Name: Burkholderia_CCGE1002_uid42523, Order: ['1484', '4584']
# 	Genome ID: NC_012718, Creature Name: Burkholderia_glumae_BGR1_uid59397, Order: ['4584', '1484']
# 	Genome ID: NC_012720, Creature Name: Burkholderia_glumae_BGR1_uid59397, Order: ['4584', '1484']
# 	Genome ID: NC_012723, Creature Name: Burkholderia_glumae_BGR1_uid59397, Order: ['4584', '1484']
# 	Genome ID: NC_010070, Creature Name: Burkholderia_multivorans_ATCC_17616_uid58697, Order: ['4584', '1484']
# 	Genome ID: NC_010802, Creature Name: Burkholderia_multivorans_ATCC_17616_uid58909, Order: ['4584', '1484']
# 	Genome ID: NC_010627, Creature Name: Burkholderia_phymatum_STM815_uid58699, Order: ['4584', '1484']
# 	Genome ID: NC_014718, Creature Name: Burkholderia_rhizoxinica_HKI_454_uid60487, Order: ['4584', '1484']
# 	Genome ID: NC_014723, Creature Name: Burkholderia_rhizoxinica_HKI_454_uid60487, Order: ['4584', '1484']
# 	Genome ID: NC_009227, Creature Name: Burkholderia_vietnamiensis_G4_uid58075, Order: ['4584', '1484']
# 	Genome ID: NC_009228, Creature Name: Burkholderia_vietnamiensis_G4_uid58075, Order: ['4584', '1484']
# 	Genome ID: NC_009230, Creature Name: Burkholderia_vietnamiensis_G4_uid58075, Order: ['4584', '1484']
# 	Genome ID: NC_013190, Creature Name: Candidatus_Accumulibacter_phosphatis_clade_IIA_UW_1_uid59207, Order: ['4584', '1484']
# 	Genome ID: NC_013193, Creature Name: Candidatus_Accumulibacter_phosphatis_clade_IIA_UW_1_uid59207, Order: ['4584', '1484']
# 	Genome ID: NC_010333, Creature Name: Caulobacter_K31_uid58551, Order: ['4584', '1484']
# 	Genome ID: NC_015417, Creature Name: Clostridium_botulinum_BKT015925_uid66203, Order: ['4584', '1484']
# 	Genome ID: NC_015418, Creature Name: Clostridium_botulinum_BKT015925_uid66203, Order: ['4584', '1484']
# 	Genome ID: NC_015426, Creature Name: Clostridium_botulinum_BKT015925_uid66203, Order: ['4584', '1484']
# 	Genome ID: NC_007972, Creature Name: Cupriavidus_metallidurans_CH34_uid57815, Order: ['4584', '1484']
# 	Genome ID: NC_015727, Creature Name: Cupriavidus_necator_N_1_uid68689, Order: ['4584', '1484']
# 	Genome ID: NC_010529, Creature Name: Cupriavidus_taiwanensis_LMG_19424_uid61615, Order: ['4584', '1484']
# 	Genome ID: NC_008010, Creature Name: Deinococcus_geothermalis_DSM_11300_uid58275, Order: ['4584', '1484']
# 	Genome ID: NC_009837, Creature Name: Escherichia_coli_APEC_O1_uid58623, Order: ['4584', '1484']
# 	Genome ID: NC_009788, Creature Name: Escherichia_coli_E24377A_uid58395, Order: ['4584', '1484']
# 	Genome ID: NC_009790, Creature Name: Escherichia_coli_E24377A_uid58395, Order: ['4584', '1484']
# 	Genome ID: NC_011747, Creature Name: Escherichia_coli_S88_uid62979, Order: ['4584', '1484']
# 	Genome ID: NC_011749, Creature Name: Escherichia_coli_UMN026_uid62981, Order: ['4584', '1484']
# 	Genome ID: NC_007941, Creature Name: Escherichia_coli_UTI89_uid58541, Order: ['4584', '1484']
# 	Genome ID: NC_009329, Creature Name: Geobacillus_thermodenitrificans_NG80_2_uid58829, Order: ['4584', '1484']
# 	Genome ID: NC_010815, Creature Name: Geobacter_lovleyi_SZ_uid58713, Order: ['4584', '1484']
# 	Genome ID: NC_016028, Creature Name: Gluconacetobacter_xylinus_NBRC_3288_uid46523, Order: ['4584', '1484']
# 	Genome ID: NC_006625, Creature Name: Klebsiella_pneumoniae_NTUH_K2044_uid59073, Order: ['4584', '1484']
# 	Genome ID: NC_006365, Creature Name: Legionella_pneumophila_Paris_uid58211, Order: ['4584', '1484']
# 	Genome ID: NC_008738, Creature Name: Marinobacter_aquaeolei_VT8_uid59419, Order: ['4584', '1484']
# 	Genome ID: NC_010373, Creature Name: Methylobacterium_4_46_uid58843, Order: ['4584', '1484']
# 	Genome ID: NC_011758, Creature Name: Methylobacterium_chloromethanicum_CM4_uid58933, Order: ['4584', '1484']
# 	Genome ID: NC_012987, Creature Name: Methylobacterium_extorquens_DM4_uid61617, Order: ['4584', '1484']
# 	Genome ID: NC_008703, Creature Name: Mycobacterium_KMS_uid58491, Order: ['4584', '1484']
# 	Genome ID: NC_015579, Creature Name: Novosphingobium_PP1Y_uid67383, Order: ['4584', '1484']
# 	Genome ID: NC_008607, Creature Name: Pelobacter_propionicus_DSM_2379_uid58255, Order: ['4584', '1484']
# 	Genome ID: NC_011143, Creature Name: Phenylobacterium_zucineum_HLK1_uid58959, Order: ['4584', '1484']
# 	Genome ID: NC_007949, Creature Name: Polaromonas_JS666_uid58207, Order: ['4584', '1484']
# 	Genome ID: NC_007950, Creature Name: Polaromonas_JS666_uid58207, Order: ['4584', '1484']
# 	Genome ID: NC_008757, Creature Name: Polaromonas_naphthalenivorans_CJ2_uid58273, Order: ['4584', '1484']
# 	Genome ID: NC_008761, Creature Name: Polaromonas_naphthalenivorans_CJ2_uid58273, Order: ['4584', '1484']
# 	Genome ID: NC_015258, Creature Name: Polymorphum_gilvum_SL003B_26A1_uid65447, Order: ['4584', '1484']
# 	Genome ID: NC_004632, Creature Name: Pseudomonas_syringae_tomato_DC3000_uid57967, Order: ['4584', '1484']
# 	Genome ID: NC_012855, Creature Name: Ralstonia_pickettii_12D_uid58859, Order: ['4584', '1484']
# 	Genome ID: NC_003296, Creature Name: Ralstonia_solanacearum_GMI1000_uid57593, Order: ['4584', '1484']
# 	Genome ID: NC_007762, Creature Name: Rhizobium_etli_CFN_42_uid58377, Order: ['4584', '1484']
# 	Genome ID: NC_000914, Creature Name: Rhizobium_NGR234_uid59081, Order: ['4584', '1484']
# 	Genome ID: NC_012586, Creature Name: Rhizobium_NGR234_uid59081, Order: ['4584', '1484']
# 	Genome ID: NC_009429, Creature Name: Rhodobacter_sphaeroides_ATCC_17025_uid58451, Order: ['4584', '1484']
# 	Genome ID: NC_007491, Creature Name: Rhodococcus_erythropolis_PR4_uid59019, Order: ['4584', '1484']
# 	Genome ID: NC_008269, Creature Name: Rhodococcus_jostii_RHA1_uid58325, Order: ['4584', '1484']
# 	Genome ID: NC_012521, Creature Name: Rhodococcus_opacus_B4_uid13791, Order: ['4584', '1484']
# 	Genome ID: NC_014825, Creature Name: Ruminococcus_albus_7_uid51721, Order: ['4584', '1484']
# 	Genome ID: NC_015704, Creature Name: Runella_slithyformis_DSM_19594_uid68317, Order: ['4584', '1484']
# 	Genome ID: NC_006856, Creature Name: Salmonella_enterica_serovar_Choleraesuis_SC_B67_uid58017, Order: ['4584', '1484']
# 	Genome ID: NC_009140, Creature Name: Salmonella_enterica_serovar_Newport_SL254_uid58831, Order: ['4584', '1484']
# 	Genome ID: NC_011092, Creature Name: Salmonella_enterica_serovar_Schwarzengrund_CVM19633_uid58915, Order: ['4584', '1484']
# 	Genome ID: NC_009036, Creature Name: Shewanella_baltica_OS155_uid58259, Order: ['4584', '1484']
# 	Genome ID: NC_010660, Creature Name: Shigella_boydii_CDC_3083_94_uid58415, Order: ['4584', '1484']
# 	Genome ID: NC_007607, Creature Name: Shigella_dysenteriae_Sd197_uid58213, Order: ['4584', '1484']
# 	Genome ID: NC_004851, Creature Name: Shigella_flexneri_2a_301_uid62907, Order: ['4584', '1484']
# 	Genome ID: NC_007385, Creature Name: Shigella_sonnei_Ss046_uid58217, Order: ['4584', '1484']
# 	Genome ID: NC_009621, Creature Name: Sinorhizobium_medicae_WSM419_uid58549, Order: ['4584', '1484']
# 	Genome ID: NC_009622, Creature Name: Sinorhizobium_medicae_WSM419_uid58549, Order: ['4584', '1484']
# 	Genome ID: NC_003037, Creature Name: Sinorhizobium_meliloti_1021_uid57603, Order: 
# 	Genome ID: NC_006153, Creature Name: Yersinia_pseudotuberculosis_IP_32953_uid58157, Order: ['4584', '1484']
# 	Genome ID: NC_010635, Creature Name: Yersinia_pseudotuberculosis_PB1__uid59153, Order: ['4584', '1484']
# First Instance of this Cluster: ['4584', '1484']
# Information about the COG's:
# 	 COG 1484 : L;INFORMATION STORAGE AND PROCESSING;Replication, recombination and repair;DNA replication protein DnaC
# 	 COG 4584 : X;MOBILOME;Mobilome: prophages, transposons;Transposase
# Statistics about the different orders we found:
# 	 [ 4584, 1484 ]: 127 times out of 128 which is 99.22 percent
# 	 [ 1484, 4584 ]: 1 times out of 128 which is 0.78 percent
# Statistics about the Phylum:
# 	 Order: [ 4584, 1484 ] - Appears in these Phylum:
# 		 Cyanobacteria - 1 times out of 127 ,which is 0.79 percent
# 		 Proteobacteria - 105 times out of 127 ,which is 82.68 percent
# 		 Actinobacteria - 8 times out of 127 ,which is 6.3 percent
# 		 Firmicutes - 9 times out of 127 ,which is 7.09 percent
# 		 - - 1 times out of 127 ,which is 0.79 percent
# 		 Bacteroidetes - 3 times out of 127 ,which is 2.36 percent
# 	 Order: [ 1484, 4584 ] - Appears in these Phylum:
# 		 Proteobacteria - 1 times out of 1 ,which is 100.0 percent
# Statistics about the Habitat:
# 	 Order: [ 4584, 1484 ] - Appears in these Habitats:
# 		 Marine Environment - 9 times out of 127 ,which is 7.09 percent
# 		 Not Annotated - 9 times out of 127 ,which is 7.09 percent
# 		 Soil and Sediment - 41 times out of 127 ,which is 32.28 percent
# 		 Animal - 6 times out of 127 ,which is 4.72 percent
# 		 Plant - 19 times out of 127 ,which is 14.96 percent
# 		 Wastewater - 6 times out of 127 ,which is 4.72 percent
# ...
# 	Genome ID: NC_014731, Creature Name: Halogeometricum_borinquense_DSM_11551_uid54919, Order: ['3839', '1653', '1175', '0395']
# 	Genome ID: NC_014735, Creature Name: Halogeometricum_borinquense_DSM_11551_uid54919, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_013201, Creature Name: Halomicrobium_mukohataei_DSM_12286_uid59107, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_015658, Creature Name: Halopiger_xanaduensis_SH_6_uid68105, Order: ['3839', '1653', '1175', '0395']
# 	Genome ID: NC_013744, Creature Name: Haloterrigena_turkmenica_DSM_5511_uid43501, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_013745, Creature Name: Haloterrigena_turkmenica_DSM_5511_uid43501, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_014621, Creature Name: Ketogulonicigenium_vulgare_Y25_uid59581, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_014918, Creature Name: Mesorhizobium_ciceri_biovar_biserrulae_WSM1271_uid62101, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_014839, Creature Name: Pantoea_At_9b_uid55845, Order: ['3839', '1653', '1175', '0395']
# 	Genome ID: NC_008688, Creature Name: Paracoccus_denitrificans_PD1222_uid58187, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_007763, Creature Name: Rhizobium_etli_CFN_42_uid58377, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_007764, Creature Name: Rhizobium_etli_CFN_42_uid58377, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_007765, Creature Name: Rhizobium_etli_CFN_42_uid58377, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_007766, Creature Name: Rhizobium_etli_CFN_42_uid58377, Order: ['3839', '1653', '1175', '0395']
# 	Genome ID: NC_010997, Creature Name: Rhizobium_etli_CIAT_652_uid59115, Order: ['3839', '1653', '1175', '0395']
# 	Genome ID: NC_010998, Creature Name: Rhizobium_etli_CIAT_652_uid59115, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_012848, Creature Name: Rhizobium_leguminosarum_bv__trifolii_WSM1325_uid58991, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_012852, Creature Name: Rhizobium_leguminosarum_bv__trifolii_WSM1325_uid58991, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_012853, Creature Name: Rhizobium_leguminosarum_bv__trifolii_WSM1325_uid58991, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_012854, Creature Name: Rhizobium_leguminosarum_bv__trifolii_WSM1325_uid58991, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_012858, Creature Name: Rhizobium_leguminosarum_bv__trifolii_WSM1325_uid58991, Order: ['1175', '0395', '1653', '3839']
# 	Genome ID: NC_011366, Creature Name: Rhizobium_leguminosarum_bv__trifolii_WSM2304_uid58997, Order: ['1175', '0395', '1653', '3839']
# 	Genome ID: NC_011368, Creature Name: Rhizobium_leguminosarum_bv__trifolii_WSM2304_uid58997, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_011371, Creature Name: Rhizobium_leguminosarum_bv__trifolii_WSM2304_uid58997, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_008378, Creature Name: Rhizobium_leguminosarum_bv__viciae_3841_uid57955, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_008379, Creature Name: Rhizobium_leguminosarum_bv__viciae_3841_uid57955, Order: ['3839', '1175', '0395', '1653']
# 	Genome ID: NC_008381, Creature Name: Rhizobium_leguminosarum_bv__viciae_3841_uid57955, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_008383, Creature Name: Rhizobium_leguminosarum_bv__viciae_3841_uid57955, Order: ['1175', '0395', '1653', '3839']
# 	Genome ID: NC_008384, Creature Name: Rhizobium_leguminosarum_bv__viciae_3841_uid57955, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_000914, Creature Name: Rhizobium_NGR234_uid59081, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_012586, Creature Name: Rhizobium_NGR234_uid59081, Order: ['1175', '0395', '1653', '3839']
# 	Genome ID: NC_014035, Creature Name: Rhodobacter_capsulatus_SB_1003_uid47509, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_007488, Creature Name: Rhodobacter_sphaeroides_2_4_1_uid57653, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_009429, Creature Name: Rhodobacter_sphaeroides_ATCC_17025_uid58451, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_011962, Creature Name: Rhodobacter_sphaeroides_KD131_uid59277, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_008043, Creature Name: Ruegeria_TM1040_uid58193, Order: ['3839', '1653', '1175', '0395']
# 	Genome ID: NC_009620, Creature Name: Sinorhizobium_medicae_WSM419_uid58549, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_003037, Creature Name: Sinorhizobium_meliloti_1021_uid57603, Order: ['1653', '1175', '0395', '3839']
# 	Genome ID: NC_003078, Creature Name: Sinorhizobium_meliloti_1021_uid57603, Order: ['1653', '1175', '0395', '3839']
# First Instance of this Cluster: ['1653', '1175', '0395', '3839']
# Information about the COG's:
# 	 COG 0395 : G;METABOLISM;Carbohydrate transport and metabolism;ABC-type glycerol-3-phosphate transport system, permease component
# 	 COG 1175 : G;METABOLISM;Carbohydrate transport and metabolism;ABC-type sugar transport system, permease component
# 	 COG 1653 : G;METABOLISM;Carbohydrate transport and metabolism;ABC-type glycerol-3-phosphate transport system, periplasmic component
# 	 COG 3839 : G;METABOLISM;Carbohydrate transport and metabolism;ABC-type sugar transport system, ATPase component
# Statistics about the different orders we found:
# 	 [ 1653, 1175, 0395, 3839 ]: 40 times out of 52 which is 76.92 percent
# 	 [ 3839, 1653, 1175, 0395 ]: 7 times out of 52 which is 13.46 percent
# 	 [ 1175, 0395, 1653, 3839 ]: 4 times out of 52 which is 7.69 percent
# 	 [ 3839, 1175, 0395, 1653 ]: 1 times out of 52 which is 1.92 percent
# Statistics about the Phylum:
# 	 Order: [ 1653, 1175, 0395, 3839 ] - Appears in these Phylum:
# 		 Proteobacteria - 30 times out of 40 ,which is 75.0 percent
# 		 Euryarchaeota - 10 times out of 40 ,which is 25.0 percent
# 	 Order: [ 3839, 1653, 1175, 0395 ] - Appears in these Phylum:
# 		 Proteobacteria - 5 times out of 7 ,which is 71.43 percent
# 		 Euryarchaeota - 2 times out of 7 ,which is 28.57 percent
# 	 Order: [ 1175, 0395, 1653, 3839 ] - Appears in these Phylum:
# 		 Proteobacteria - 4 times out of 4 ,which is 100.0 percent
# 	 Order: [ 3839, 1175, 0395, 1653 ] - Appears in these Phylum:
# 		 Proteobacteria - 1 times out of 1 ,which is 100.0 percent
# Statistics about the Habitat:
# 	 Order: [ 1653, 1175, 0395, 3839 ] - Appears in these Habitats:
# 		 Plant - 9 times out of 40 ,which is 22.5 percent
# 		 Soil and Sediment - 16 times out of 40 ,which is 40.0 percent
# 		 Not Annotated - 12 times out of 40 ,which is 30.0 percent
# 		 Wastewater - 1 times out of 40 ,which is 2.5 percent
# 		 Host - 2 times out of 40 ,which is 5.0 percent
# 	 Order: [ 3839, 1653, 1175, 0395 ] - Appears in these Habitats:
# 		 Plant - 2 times out of 7 ,which is 28.57 percent
# 		 Not Annotated - 2 times out of 7 ,which is 28.57 percent
# 		 Host - 1 times out of 7 ,which is 14.29 percent
Creature Name: Rhizobium_etli_CIAT_652_uid59115, Order: ['0683', '0559', '4177', '0411']
# 	Genome ID: NC_011368, Creature Name: Rhizobium_leguminosarum_bv__trifolii_WSM2304_uid58997, Order: ['0683', '0559', '4177', '0411']
# 	Genome ID: NC_008378, Creature Name: Rhizobium_leguminosarum_bv__viciae_3841_uid57955, Order: ['0683', '0559', '4177', '0411']
# 	Genome ID: NC_008379, Creature Name: Rhizobium_leguminosarum_bv__viciae_3841_uid57955, Order: ['0683', '0559', '4177', '0411']
# 	Genome ID: NC_008381, Creature Name: Rhizobium_leguminosarum_bv__viciae_3841_uid57955, Order: ['0683', '0559', '4177', '0411']
# 	Genome ID: NC_008383, Creature Name: Rhizobium_leguminosarum_bv__viciae_3841_uid57955, Order: ['0683', '0559', '4177', '0411']
# 	Genome ID: NC_012586, Creature Name: Rhizobium_NGR234_uid59081, Order: ['0683', '0559', '4177', '0411']
# 	Genome ID: NC_007488, Creature Name: Rhodobacter_sphaeroides_2_4_1_uid57653, Order: ['0683', '0559', '4177', '0411']
# 	Genome ID: NC_009429, Creature Name: Rhodobacter_sphaeroides_ATCC_17025_uid58451, Order: ['0683', '0559', '4177', '0411']
# 	Genome ID: NC_011962, Creature Name: Rhodobacter_sphaeroides_KD131_uid59277, Order: ['0683', '0559', '4177', '0411']
# 	Genome ID: NC_006569, Creature Name: Ruegeria_pomeroyi_DSS_3_uid57863, Order: ['0683', '0559', '4177', '0411']
# 	Genome ID: NC_009620, Creature Name: Sinorhizobium_medicae_WSM419_uid58549, Order: ['0683', '0559', '4177', '0411']
# 	Genome ID: NC_003078, Creature Name: Sinorhizobium_meliloti_1021_uid57603, Order: ['0683', '0559', '4177', '0411']
# 	Genome ID: NC_011961, Creature Name: Thermomicrobium_roseum_DSM_5159_uid59341, Order: ['0559', '4177', '0683', '0411']
# 	Genome ID: NC_009717, Creature Name: Xanthobacter_autotrophicus_Py2_uid58453, Order: ['0411', '0559', '4177', '0683']
# First Instance of this Cluster: ['0683', '0559', '4177', '0411']
# Information about the COG's:
# 	 COG 0411 : E;METABOLISM;Amino acid transport and metabolism;ABC-type branched-chain amino acid transport system, ATPase component
# 	 COG 0559 : E;METABOLISM;Amino acid transport and metabolism;Branched-chain amino acid ABC-type transport system, permease component
# 	 COG 0683 : E;METABOLISM;Amino acid transport and metabolism;ABC-type branched-chain amino acid transport system, periplasmic component
# 	 COG 4177 : E;METABOLISM;Amino acid transport and metabolism;ABC-type branched-chain amino acid transport system, permease component
# Statistics about the different orders we found:
# 	 [ 0683, 0559, 4177, 0411 ]: 44 times out of 50 which is 88.0 percent
# 	 [ 0411, 0559, 4177, 0683 ]: 5 times out of 50 which is 10.0 percent
# 	 [ 0559, 4177, 0683, 0411 ]: 1 times out of 50 which is 2.0 percent
# Statistics about the Phylum:
# 	 Order: [ 0683, 0559, 4177, 0411 ] - Appears in these Phylum:
# 		 Proteobacteria - 37 times out of 44 ,which is 84.09 percent
# 		 Euryarchaeota - 7 times out of 44 ,which is 15.91 percent
# 	 Order: [ 0411, 0559, 4177, 0683 ] - Appears in these Phylum:
# 		 Proteobacteria - 5 times out of 5 ,which is 100.0 percent
# 	 Order: [ 0559, 4177, 0683, 0411 ] - Appears in these Phylum:
# 		 Chloroflexi - 1 times out of 1 ,which is 100.0 percent
# Statistics about the Habitat:
# 	 Order: [ 0683, 0559, 4177, 0411 ] - Appears in these Habitats:
# 		 Soil and Sediment - 16 times out of 44 ,which is 36.36 percent
# 		 Marine Environment - 2 times out of 44 ,which is 4.55 percent
# 		 Plant - 7 times out of 44 ,which is 15.91 percent
# 		 Host - 3 times out of 44 ,which is 6.82 percent
# 		 Not Annotated - 10 times out of 44 ,which is 22.73 percent
# 		 Animal - 1 times out of 44 ,which is 2.27 percent
# 		 Wastewater - 1 times out of 44 ,which is 2.27 percent
# 		 Fresh water - 3 times out of 44 ,which is 6.82 percent
# 		 Extreme Environments - 1 times out of 44 ,which is 2.27 percent
# 	 Order: [ 0411, 0559, 4177, 0683 ] - Appears in these Habitats:
# 		 Plant - 3 times out of 5 ,which is 60.0 percent
# 		 Fresh water - 2 times out of 5 ,which is 40.0 percent
# 	 Order: [ 0559, 4177, 0683, 0411 ] - Appears in these Habitats:
# 		 Extreme Environments - 1 times out of 1 ,which is 100.0 percent
#
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
